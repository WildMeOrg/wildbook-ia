# %%
# Set global utool flags
import utool as ut
ut.util_io.__PRINT_WRITES__ = False
ut.util_io.__PRINT_READS__ = False
ut.util_parallel.__FORCE_SERIAL__ = True
ut.util_cache.VERBOSE_CACHE = False
ut.NOT_QUIET = False

# Matplotlib stuff
# %pylab inline
# %load_ext autoreload
# %autoreload

# Define database for this test run
import ibeis
#db = 'PZ_Master1'
#db = 'GZ_ALL'
db = 'NNP_MasterGIRM_core'
 
# Setup database specific configs
if db == 'PZ_MTEST' or db == 'GZ_ALL':
    seperability_annot_cfgs = ['ctrl']
else:
    seperability_annot_cfgs = ['timequalctrl']

if db == 'PZ_Master1':
    varysize = ['varysize_pzm']
    varypername = ['varypername_pzm']
elif db == 'GZ_ALL':
    varysize = ['varysize_gz']
    varypername = ['varypername_gz']
elif db == 'NNP_MasterGIRM_core':
    varysize = ['varysize_girm']
    varypername = ['varypername_girm']
# Out:
# WARNING: pylab import has clobbered these variables: ['split']
# `%matplotlib` prevents importing * from pylab and numpy
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1318: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Baseline Experiments

# %%
test_result = ibeis.run_experiment(
    e='rank_cdf', 
    db=db, 
    a=['unctrl', 'ctrl::unctrl:qpername=1,qview_ext=0'],
    t=['baseline'])
#test_result.print_unique_annot_config_stats()
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e rank_cdf --db NNP_MasterGIRM_core -a unctrl ctrl::unctrl:qpername=1,qview_ext=0 -t baseline --show
#
# [ibs.__init__] new IBEISController
# [ibs._init_dirs] ibs.dbdir = '/media/raid/work/NNP_MasterGIRM_core'
# WARNING: UNKNOWN CFGNAME='giraffe_masai'
# [ibs.__init__] END new IBEISController

# %%
# Baseline Timedeltas FP
test_result = ibeis.run_experiment(
    e='timedelta_hist',
    db=db, 
    a=['ctrl::unctrl:qpername=1,qview_ext=0'], 
    t=['baseline'],
    truepos=True)
test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e timedelta_hist --db NNP_MasterGIRM_core -a ctrl::unctrl:qpername=1,qview_ext=0 -t baseline --show

# %%
# Baseline Timedeltas FP
test_result = ibeis.run_experiment(
    e='timedelta_hist',
    db=db, 
    a=['ctrl::unctrl:qpername=1,qview_ext=0'], 
    t=['baseline'],
    falsepos=True)
test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e timedelta_hist --db NNP_MasterGIRM_core -a ctrl::unctrl:qpername=1,qview_ext=0 -t baseline --show

# %%
# Time Experiment 
test_result = ibeis.run_experiment(
    e='rank_cdf',
    db=db, 
    a=['largetimedelta', 'ctrl'], 
    t=['baseline'])
test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e rank_cdf --db NNP_MasterGIRM_core -a largetimedelta ctrl -t baseline --show

# %%
# Timedelta PIE for new False Pos 
test_result = ibeis.run_experiment(
    e='timedelta_hist',
    db=db, 
    a=['largetimedelta'], 
    t=['baseline'],
    falsepos=True)
test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e timedelta_hist --db NNP_MasterGIRM_core -a largetimedelta -t baseline --show

# %% [markdown]
# # Database Size Experiments

# %%
# K Experiment 
test_result = ibeis.run_experiment(
    e='rank_surface',
    db=db, 
    a=varysize, 
    t=['candidacy_k'])
#test_result.print_unique_annot_config_stats()
test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e rank_surface --db NNP_MasterGIRM_core -a varysize_girm -t candidacy_k --show

# %% [markdown]
# # Scoring Mechanism Experiments

# %%
# Namescore Experiment
test_result = ibeis.run_experiment(
    e='rank_cdf',
    db=db, 
    a=varypername, 
    t=['candidacy_namescore'])
test_result.print_unique_annot_config_stats()
test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e rank_cdf --db NNP_MasterGIRM_core -a varypername_girm -t candidacy_namescore --show
# Sampling could not get exactly right sample size
# Warning: Cannot meet sample_size=93. available_daids will be oversized by at least 15
# Warning: Cannot meet sample_size=93. available_daids will be oversized by at least 15
# [acfgstats]+====
# [acfgstats]Printing 3 unique annotconfig stats
# [acfgstats]test_result.common_acfg = {
# [acfgstats]    'common': {
# [acfgstats]        '_cfgname': 'varypername_girm',
# [acfgstats]        '_cfgstr': 'varypername_girm',
# [acfgstats]        'force_const_size': True,
# [acfgstats]        'is_known': True,
# [acfgstats]        'minqual': 'ok',
# [acfgstats]        'sample_rule': 'random',
# [acfgstats]        'sample_rule_ref': 'random',
# [acfgstats]        'shuffle': False,
# [acfgstats]        'species': 'primary',
# [acfgstats]        'view': 'primary',
# [acfgstats]        'view_ext': 0,
# [acfgstats]    },
# [acfgstats]    'dcfg': {
# [acfgstats]        '_cfgtype': 'dcfg',
# [acfgstats]        '_orig_sample_size': None,
# [acfgstats]        'exclude_reference': True,
# [acfgstats]        'min_pername': 1,
# [acfgstats]        'sample_size': 93,
# [acfgstats]    },
# [acfgstats]    'qcfg': {
# [acfgstats]        '_cfgindex': 0,
# [acfgstats]        '_cfgtype': 'qcfg',
# [acfgstats]        '_orig_sample_size': 36,
# [acfgstats]        'exclude_reference': None,
# [acfgstats]        'min_pername': 4,
# [acfgstats]        'sample_per_name': 1,
# [acfgstats]        'sample_per_ref_name': None,
# [acfgstats]        'sample_size': 36,
# [acfgstats]    },
# [acfgstats]}
# [acfgstats]param_basis(len(daids)) = [93, 108]
# [acfgstats]+---
# [acfgstats]acfgx = 0/3
# [acfgstats]annot_config_stats = {
# [acfgstats]    'dbname': NNP_MasterGIRM_core,
# [acfgstats]    'num_qaids': 36,
# [acfgstats]    'num_daids': 93,
# [acfgstats]    'num_annot_intersect': 0,
# [acfgstats]    'qaid_stats': {
# [acfgstats]        'num_qaids': 36,
# [acfgstats]        'qhashid': _QSUUIDS((36)7lrvlqc43qj4zxjc),
# [acfgstats]        'qper_name': {max: 1, min: 1, mean: 1, std: 0.00, nMin: 36, nMax: 36, shape: (36,)},
# [acfgstats]        'qper_vp': {L: 36},
# [acfgstats]    },
# [acfgstats]    'daid_stats': {
# [acfgstats]        'num_daids': 93,
# [acfgstats]        'dhashid': _DSUUIDS((93)x933t7vssx136z%x),
# [acfgstats]        'dper_name': {max: 1, min: 1, mean: 1, std: 0.00, nMin: 93, nMax: 93, shape: (93,)},
# [acfgstats]        'dper_vp': {L: 93},
# [acfgstats]    },
# [acfgstats]    'num_unmatchable_queries': 0,
# [acfgstats]    'num_matchable_queries': 36,
# [acfgstats]    'num_name_intersect': 36,
# [acfgstats]    'per_name_genuine': {max: 1, min: 1, mean: 1, std: 0.00, nMin: 36, nMax: 36, shape: (36,)},
# [acfgstats]    'per_name_imposter': {max: 1, min: 1, mean: 1, std: 0.00, nMin: 57, nMax: 57, shape: (57,)},
# [acfgstats]    'viewdist': {max: 0.11, min: 0.00, mean: 0.00, std: 0.02, nMin: 35, nMax: 1, shape: (36,)},
# [acfgstats]    'hourdist': {max: 235.24, min: 0.00, mean: 24.06, std: 61.44, nMin: 1, nMax: 1, shape: (36,)},
# [acfgstats]}
# [acfgstats]L___
# [acfgstats]+---
# [acfgstats]acfgx = 1/3
# [acfgstats]annot_config_stats = {
# [acfgstats]    'dbname': NNP_MasterGIRM_core,
# [acfgstats]    'num_qaids': 36,
# [acfgstats]    'num_daids': 108,
# [acfgstats]    'num_annot_intersect': 0,
# [acfgstats]    'qaid_stats': {
# [acfgstats]        'num_qaids': 36,
# [acfgstats]        'qhashid': _QSUUIDS((36)7lrvlqc43qj4zxjc),
# [acfgstats]        'qper_name': {max: 1, min: 1, mean: 1, std: 0.00, nMin: 36, nMax: 36, shape: (36,)},
# [acfgstats]        'qper_vp': {L: 36},
# [acfgstats]    },
# [acfgstats]    'daid_stats': {
# [acfgstats]        'num_daids': 108,
# [acfgstats]        'dhashid': _DSUUIDS((108)3qub85vdx4@me@oz),
# [acfgstats]        'dper_name': {max: 3, min: 3, mean: 3, std: 0.00, nMin: 36, nMax: 36, shape: (36,)},
# [acfgstats]        'dper_vp': {L: 108},
# [acfgstats]    },
# [acfgstats]    'num_unmatchable_queries': 0,
# [acfgstats]    'num_matchable_queries': 36,
# [acfgstats]    'num_name_intersect': 36,
# [acfgstats]    'per_name_genuine': {max: 3, min: 3, mean: 3, std: 0.00, nMin: 36, nMax: 36, shape: (36,)},
# [acfgstats]    'per_name_imposter': {empty_list: True},
# [acfgstats]    'viewdist': {max: 0.11, min: 0.00, mean: 0.00, std: 0.02, nMin: 105, nMax: 3, shape: (108,)},
# [acfgstats]    'hourdist': {max: 235.54, min: 0.00, mean: 24.92, std: 59.35, nMin: 1, nMax: 1, shape: (108,), num_nan: 1},
# [acfgstats]}
# [acfgstats]L___
# [acfgstats]+---
# [acfgstats]acfgx = 2/3
# [acfgstats]annot_config_stats = {
# [acfgstats]    'dbname': NNP_MasterGIRM_core,
# [acfgstats]    'num_qaids': 36,
# [acfgstats]    'num_daids': 93,
# [acfgstats]    'num_annot_intersect': 0,
# [acfgstats]    'qaid_stats': {
# [acfgstats]        'num_qaids': 36,
# [acfgstats]        'qhashid': _QSUUIDS((36)7lrvlqc43qj4zxjc),
# [acfgstats]        'qper_name': {max: 1, min: 1, mean: 1, std: 0.00, nMin: 36, nMax: 36, shape: (36,)},
# [acfgstats]        'qper_vp': {L: 36},
# [acfgstats]    },
# [acfgstats]    'daid_stats': {
# [acfgstats]        'num_daids': 93,
# [acfgstats]        'dhashid': _DSUUIDS((93)kt+3@v+2eheb%@5k),
# [acfgstats]        'dper_name': {max: 3, min: 1, mean: 1.19, std: 0.48, nMin: 66, nMax: 3, shape: (78,)},
# [acfgstats]        'dper_vp': {L: 93},
# [acfgstats]    },
# [acfgstats]    'num_unmatchable_queries': 0,
# [acfgstats]    'num_matchable_queries': 36,
# [acfgstats]    'num_name_intersect': 36,
# [acfgstats]    'per_name_genuine': {max: 1, min: 1, mean: 1, std: 0.00, nMin: 36, nMax: 36, shape: (36,)},
# [acfgstats]    'per_name_imposter': {max: 3, min: 1, mean: 1.36, std: 0.61, nMin: 30, nMax: 3, shape: (42,)},
# [acfgstats]    'viewdist': {max: 0.11, min: 0.00, mean: 0.00, std: 0.02, nMin: 35, nMax: 1, shape: (36,)},
# [acfgstats]    'hourdist': {max: 235.24, min: 0.00, mean: 24.06, std: 61.44, nMin: 1, nMax: 1, shape: (36,)},
# [acfgstats]}
# [acfgstats]L___

# %% [markdown]
# # Viewpoint Experiments

# %%
try:
    test_result = ibeis.run_experiment(
        e='rank_cdf',
        db=db, 
        a=['viewpoint_compare'], 
        t=['baseline'])
    test_result.draw_func()
except AssertionError as ex:
    ut.printex(ex, 'Database does not support this test')
# Out:
# Equivalent Command Line:
# ibeis -e rank_cdf --db NNP_MasterGIRM_core -a viewpoint_compare -t baseline --show

# %% [markdown]
# # Invariance Experiments

# %%
test_result = ibeis.run_experiment(
    e='rank_cdf',
    db=db, 
    a=['ctrl'], 
    t=['candidacy_invariance'])
test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e rank_cdf --db NNP_MasterGIRM_core -a ctrl -t candidacy_invariance --show

# %%
# Invariance + Viewpoint Experiment
try:
    test_result = ibeis.run_experiment(
        e='rank_cdf',
        db=db, 
        a=['viewpoint_compare'], 
        t=['candidacy_invariance'], 
        test_cfgx_slice=slice(6, None))
    test_result.draw_func()
except AssertionError as ex:
    ut.printex(ex, 'Database does not support this test')
# Out:
# Equivalent Command Line:
# ibeis -e rank_cdf --db NNP_MasterGIRM_core -a viewpoint_compare -t candidacy_invariance --test_cfgx_slice 6:: --show
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)r16oc0@y&&9dgotb)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_)_CHIP(sz450)
# pipe_hashstr = puxdfqnysbshylgi
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)r16oc0@y&&9dgotb)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_rotation_invariance=True)_CHIP(sz450)
# pipe_hashstr = lfafclerifuhzbyc
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)r16oc0@y&&9dgotb)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_rotation_invariance=True,affine_invariance=False)_CHIP(sz450)
# pipe_hashstr = tgjyvnestslpmgdn
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)r16oc0@y&&9dgotb)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_affine_invariance=False)_CHIP(sz450)
# pipe_hashstr = udipwbdwtdkmsfab
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)r16oc0@y&&9dgotb)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_)_CHIP(sz450)_HACK(augment_queryside)
# pipe_hashstr = gdstujchlpfftasy
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/12][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/12][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/12][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((20636,128)2e1q@gv!47k&x040).flann'
# [NNP_MasterGIRM_core cfg 0/12]...nnindex flann cache hit: 20636 vectors, 13 annots
# [NNP_MasterGIRM_core cfg 0/12][cache] 13/13 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/13...  rate=41526.04 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:31 EST
# Filter NN:          13/13...  rate=41526.04 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:31 EST
#
# [NNP_MasterGIRM_core cfg 0/12]Weight NN:
# Build Chipmatch:     1/13...  rate=861.25 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:31 EST
# [NNP_MasterGIRM_core cfg 0/12][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/13...  rate=0.44 Hz, etr: 0:00:27, ellapsed: 0:00:02, wall: 13:32 EST
# SVER:               13/13...  rate=0.44 Hz, etr: 0:00:00, ellapsed: 0:00:15, wall: 13:32 EST
#
# [mc4] query chunk:     1/1...  rate=0.06 Hz, etr: 0:00:00, ellapsed: 0:00:16, wall: 13:32 EST
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)r16oc0@y&&9dgotb)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_affine_invariance=False)_CHIP(sz450)_HACK(augment_queryside)
# pipe_hashstr = sckidzxjndpaqngn
# [NNP_MasterGIRM_core cfg 0/12][add_chip_feat] adding 13 / 13 new feat for config_rowid=11
# [NNP_MasterGIRM_core cfg 0/12][add_chip_feat] adding to sql in chunks with chunksize=128
# [util_parallel.generate] generate_serial
# [util_parallel._generate_serial] executing 13 gen_feat_worker tasks in serial
# gen_feat_worker:    10/13...  rate=1.29 Hz, etr: 0:00:02, ellapsed: 0:00:07, wall: 13:32 EST
# [NNP_MasterGIRM_core cfg 0/12][add_chip_feat] adding feature chunk to sql
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/12][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/12][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/12][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((23074,128)0i4!q7tv&h8kgxlu).flann'
# [NNP_MasterGIRM_core cfg 0/12]...nnindex flann cache hit: 23074 vectors, 13 annots
# Assign NN:           1/13...  rate=1.91 Hz, etr: 0:00:06, ellapsed: 0:00:00, wall: 13:32 EST
# Assign NN:          13/13...  rate=1.91 Hz, etr: 0:00:00, ellapsed: 0:00:05, wall: 13:32 EST
#
# [NNP_MasterGIRM_core cfg 0/12][cache] 0/13 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/13...  rate=34378.36 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:32 EST
# Filter NN:          13/13...  rate=34378.36 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:32 EST
#
# [NNP_MasterGIRM_core cfg 0/12]Weight NN:
# Build Chipmatch:     1/13...  rate=922.43 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:32 EST
# [NNP_MasterGIRM_core cfg 0/12][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/13...  rate=0.31 Hz, etr: 0:00:39, ellapsed: 0:00:03, wall: 13:32 EST
# SVER:               11/13...  rate=0.74 Hz, etr: 0:00:02, ellapsed: 0:00:16, wall: 13:32 EST
# SVER:               13/13...  rate=0.74 Hz, etr: 0:00:00, ellapsed: 0:00:18, wall: 13:32 EST
#
# [mc4] query chunk:     1/1...  rate=0.04 Hz, etr: 0:00:00, ellapsed: 0:00:25, wall: 13:32 EST
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)@dkjwne5h40rppox)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_)_CHIP(sz450)
# pipe_hashstr = puxdfqnysbshylgi
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)@dkjwne5h40rppox)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_rotation_invariance=True)_CHIP(sz450)
# pipe_hashstr = lfafclerifuhzbyc
# [NNP_MasterGIRM_core cfg 0/12][add_chip_feat] adding 7 / 13 new feat for config_rowid=10
# [NNP_MasterGIRM_core cfg 0/12][add_chip_feat] adding to sql in chunks with chunksize=128
# [util_parallel.generate] generate_serial
# [util_parallel._generate_serial] executing 7 gen_feat_worker tasks in serial
# gen_feat_worker:     0/7...  [NNP_MasterGIRM_core cfg 0/12][add_chip_feat] adding feature chunk to sql
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/12][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/12][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/12][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((31703,128)!elufhk4mfs3jgby).flann'
# [NNP_MasterGIRM_core cfg 0/12]...nnindex flann cache miss: 31703 vectors, 13 annots
# [NNP_MasterGIRM_core cfg 0/12][nnindex] ...building kdtree over 31703 points (this may take a sec).
# ...toc(0.3448s, "Building index")
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((31703,128)!elufhk4mfs3jgby).flann'
# Assign NN:           1/13...  rate=5.02 Hz, etr: 0:00:02, ellapsed: 0:00:00, wall: 13:32 EST
# Assign NN:          13/13...  rate=5.02 Hz, etr: 0:00:00, ellapsed: 0:00:02, wall: 13:32 EST
#
# [NNP_MasterGIRM_core cfg 0/12][cache] 0/13 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/13...  rate=35847.47 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:32 EST
# Filter NN:          13/13...  rate=35847.47 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:32 EST
#
# [NNP_MasterGIRM_core cfg 0/12]Weight NN:
# Build Chipmatch:     1/13...  rate=1170.94 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:32 EST
# [NNP_MasterGIRM_core cfg 0/12][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/13...  rate=1.88 Hz, etr: 0:00:06, ellapsed: 0:00:00, wall: 13:32 EST
# SVER:               13/13...  rate=1.88 Hz, etr: 0:00:00, ellapsed: 0:00:06, wall: 13:33 EST
#
# [mc4] query chunk:     1/1...  rate=0.10 Hz, etr: 0:00:00, ellapsed: 0:00:09, wall: 13:33 EST
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)@dkjwne5h40rppox)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_rotation_invariance=True,affine_invariance=False)_CHIP(sz450)
# pipe_hashstr = tgjyvnestslpmgdn
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/12][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/12][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/12][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((32010,128)0cobf55xrx9xwbuh).flann'
# [NNP_MasterGIRM_core cfg 0/12]...nnindex flann cache miss: 32010 vectors, 13 annots
# [NNP_MasterGIRM_core cfg 0/12][nnindex] ...building kdtree over 32010 points (this may take a sec).
# ...toc(0.3496s, "Building index")
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((32010,128)0cobf55xrx9xwbuh).flann'
# Assign NN:           1/13...  rate=5.37 Hz, etr: 0:00:02, ellapsed: 0:00:00, wall: 13:33 EST
# Assign NN:          13/13...  rate=5.37 Hz, etr: 0:00:00, ellapsed: 0:00:02, wall: 13:33 EST
#
# [NNP_MasterGIRM_core cfg 0/12][cache] 0/13 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/13...  rate=27059.29 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
# Filter NN:          13/13...  rate=27059.29 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
#
# [NNP_MasterGIRM_core cfg 0/12]Weight NN:
# Build Chipmatch:     1/13...  rate=1582.16 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
# [NNP_MasterGIRM_core cfg 0/12][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/13...  rate=1.84 Hz, etr: 0:00:06, ellapsed: 0:00:00, wall: 13:33 EST
# SVER:               13/13...  rate=1.84 Hz, etr: 0:00:00, ellapsed: 0:00:06, wall: 13:33 EST
#
# [mc4] query chunk:     1/1...  rate=0.10 Hz, etr: 0:00:00, ellapsed: 0:00:09, wall: 13:33 EST
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)@dkjwne5h40rppox)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_affine_invariance=False)_CHIP(sz450)
# pipe_hashstr = udipwbdwtdkmsfab
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/12][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/12][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/12][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((23169,128)1zcumm&pizh3zj!6).flann'
# [NNP_MasterGIRM_core cfg 0/12]...nnindex flann cache miss: 23169 vectors, 13 annots
# [NNP_MasterGIRM_core cfg 0/12][nnindex] ...building kdtree over 23169 points (this may take a sec).
# ...toc(0.2750s, "Building index")
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((23169,128)1zcumm&pizh3zj!6).flann'
# Assign NN:           1/13...  rate=5.86 Hz, etr: 0:00:02, ellapsed: 0:00:00, wall: 13:33 EST
# Assign NN:          13/13...  rate=5.86 Hz, etr: 0:00:00, ellapsed: 0:00:02, wall: 13:33 EST
#
# [NNP_MasterGIRM_core cfg 0/12][cache] 0/13 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/13...  rate=45098.01 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
# Filter NN:          13/13...  rate=45098.01 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
#
# [NNP_MasterGIRM_core cfg 0/12]Weight NN:
# Build Chipmatch:     1/13...  rate=2128.00 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
# [NNP_MasterGIRM_core cfg 0/12][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/13...  rate=6.39 Hz, etr: 0:00:01, ellapsed: 0:00:00, wall: 13:33 EST
# SVER:               13/13...  rate=6.39 Hz, etr: 0:00:00, ellapsed: 0:00:02, wall: 13:33 EST
#
# [mc4] query chunk:     1/1...  rate=0.18 Hz, etr: 0:00:00, ellapsed: 0:00:05, wall: 13:33 EST
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)@dkjwne5h40rppox)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_)_CHIP(sz450)_HACK(augment_queryside)
# pipe_hashstr = gdstujchlpfftasy
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/12][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/12][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/12][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((20630,128)7iz7j8y+s8du%y%h).flann'
# [NNP_MasterGIRM_core cfg 0/12]...nnindex flann cache hit: 20630 vectors, 13 annots
# Assign NN:           1/13...  rate=2.03 Hz, etr: 0:00:05, ellapsed: 0:00:00, wall: 13:33 EST
# Assign NN:          13/13...  rate=2.03 Hz, etr: 0:00:00, ellapsed: 0:00:05, wall: 13:33 EST
#
# [NNP_MasterGIRM_core cfg 0/12][cache] 0/13 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/13...  rate=32262.84 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
# Filter NN:          13/13...  rate=32262.84 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
#
# [NNP_MasterGIRM_core cfg 0/12]Weight NN:
# Build Chipmatch:     1/13...  rate=936.44 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
# [NNP_MasterGIRM_core cfg 0/12][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/13...  rate=0.66 Hz, etr: 0:00:18, ellapsed: 0:00:01, wall: 13:33 EST
# SVER:               13/13...  rate=0.66 Hz, etr: 0:00:00, ellapsed: 0:00:12, wall: 13:33 EST
#
# [mc4] query chunk:     1/1...  rate=0.05 Hz, etr: 0:00:00, ellapsed: 0:00:19, wall: 13:33 EST
# testnameid="NNP_MasterGIRM_core ['candidacy_invariance']['viewpoint_compare']"
# annot_cfgstr = _QSUUIDS((13)yu7oqlz1jo03v6mq)_DSUUIDS((13)@dkjwne5h40rppox)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_affine_invariance=False)_CHIP(sz450)_HACK(augment_queryside)
# pipe_hashstr = sckidzxjndpaqngn
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/12][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/12][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/12][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/12][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/12]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((23169,128)1zcumm&pizh3zj!6).flann'
# [NNP_MasterGIRM_core cfg 0/12]...nnindex flann cache hit: 23169 vectors, 13 annots
# Assign NN:           1/13...  rate=2.72 Hz, etr: 0:00:04, ellapsed: 0:00:00, wall: 13:33 EST
# Assign NN:          13/13...  rate=2.72 Hz, etr: 0:00:00, ellapsed: 0:00:04, wall: 13:33 EST
#
# [NNP_MasterGIRM_core cfg 0/12][cache] 0/13 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/13...  rate=38478.37 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
# Filter NN:          13/13...  rate=38478.37 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
#
# [NNP_MasterGIRM_core cfg 0/12]Weight NN:
# Build Chipmatch:     1/13...  rate=868.03 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:33 EST
# [NNP_MasterGIRM_core cfg 0/12][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/13...  rate=0.91 Hz, etr: 0:00:13, ellapsed: 0:00:01, wall: 13:33 EST
# SVER:               13/13...  rate=0.91 Hz, etr: 0:00:00, ellapsed: 0:00:13, wall: 13:33 EST
#
# [mc4] query chunk:     1/1...  rate=0.05 Hz, etr: 0:00:00, ellapsed: 0:00:18, wall: 13:33 EST
# test_cfgx_slice = slice(6, None, None)

# %%
# Invariance + Time Experiment
test_result = ibeis.run_experiment(
    e='rank_cdf',
    db=db, 
    a=['timectrl'], 
    t=['baseline:AQH=False,AI=True',
       'baseline:AQH=True,AI=False',
       'baseline:AQH=False,AI=False'])
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e rank_cdf --db NNP_MasterGIRM_core -a timectrl -t baseline:AQH=False,AI=True baseline:AQH=True,AI=False baseline:AQH=False,AI=False --show
# testnameid="NNP_MasterGIRM_core ['baseline:AQH=False,AI=True', 'baseline:AQH=True,AI=False', 'baseline:AQH=False,AI=False']['timectrl']"
# annot_cfgstr = _QSUUIDS((20)cjr43hke8koo4e7u)_DSUUIDS((92)w@th5%ilyps72bku)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_)_CHIP(sz450)
# pipe_hashstr = puxdfqnysbshylgi
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/3][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/3][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/3][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/3][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/3][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/3]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((143294,128)7399d1cp4gj0st4y).flann'
# [NNP_MasterGIRM_core cfg 0/3]...nnindex flann cache miss: 143294 vectors, 92 annots
# [NNP_MasterGIRM_core cfg 0/3][nnindex] ...building kdtree over 143294 points (this may take a sec).
# ...toc(1.7372s, "Building index")
# [NNP_MasterGIRM_core cfg 0/3]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((143294,128)7399d1cp4gj0st4y).flann'
# Assign NN:           1/20...  rate=6.00 Hz, etr: 0:00:03, ellapsed: 0:00:00, wall: 13:34 EST
# Assign NN:          20/20...  rate=6.00 Hz, etr: 0:00:00, ellapsed: 0:00:02, wall: 13:34 EST
#
# [NNP_MasterGIRM_core cfg 0/3][cache] 0/20 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/20...  rate=40328.22 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
# Filter NN:          20/20...  rate=40328.22 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
#
# [NNP_MasterGIRM_core cfg 0/3]Weight NN:
# Build Chipmatch:     1/20...  rate=943.39 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
# [NNP_MasterGIRM_core cfg 0/3][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/20...  rate=14.03 Hz, etr: 0:00:01, ellapsed: 0:00:00, wall: 13:34 EST
# SVER:               20/20...  rate=14.03 Hz, etr: 0:00:00, ellapsed: 0:00:01, wall: 13:34 EST
#
# [mc4] query chunk:     1/1...  rate=0.13 Hz, etr: 0:00:00, ellapsed: 0:00:07, wall: 13:34 EST
# testnameid="NNP_MasterGIRM_core ['baseline:AQH=False,AI=True', 'baseline:AQH=True,AI=False', 'baseline:AQH=False,AI=False']['timectrl']"
# annot_cfgstr = _QSUUIDS((20)cjr43hke8koo4e7u)_DSUUIDS((92)w@th5%ilyps72bku)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_affine_invariance=False)_CHIP(sz450)_HACK(augment_queryside)
# pipe_hashstr = sckidzxjndpaqngn
# [NNP_MasterGIRM_core cfg 0/3][add_chip_feat] adding 10 / 20 new feat for config_rowid=11
# [NNP_MasterGIRM_core cfg 0/3][add_chip_feat] adding to sql in chunks with chunksize=128
# [util_parallel.generate] generate_serial
# [util_parallel._generate_serial] executing 10 gen_feat_worker tasks in serial
# gen_feat_worker:     0/10...  [NNP_MasterGIRM_core cfg 0/3][add_chip_feat] adding feature chunk to sql
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/3][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/3][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/3][aug] Nothing to augment, fallback to memcache
# [NNP_MasterGIRM_core cfg 0/3][nnindex] Loading support data to build diskcached indexer
# [NNP_MasterGIRM_core cfg 0/3][nnindex] Preparing data for indexing
# [NNP_MasterGIRM_core cfg 0/3]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((160205,128)c6!%z&n0bnawm@lj).flann'
# [NNP_MasterGIRM_core cfg 0/3]...nnindex flann cache miss: 160205 vectors, 92 annots
# [NNP_MasterGIRM_core cfg 0/3][nnindex] ...building kdtree over 160205 points (this may take a sec).
# ...toc(1.9088s, "Building index")
# [NNP_MasterGIRM_core cfg 0/3]flann fpath = '/media/raid/work/NNP_MasterGIRM_core/_ibsdb/_ibeis_cache/flann/flann_FLANN((algo=kdtree,seed=42,t=8))_VECS((160205,128)c6!%z&n0bnawm@lj).flann'
# Assign NN:           1/20...  rate=2.07 Hz, etr: 0:00:09, ellapsed: 0:00:00, wall: 13:34 EST
# Assign NN:          20/20...  rate=2.07 Hz, etr: 0:00:00, ellapsed: 0:00:07, wall: 13:34 EST
#
# [NNP_MasterGIRM_core cfg 0/3][cache] 0/20 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/20...  rate=17847.78 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
# Filter NN:          20/20...  rate=17847.78 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
#
# [NNP_MasterGIRM_core cfg 0/3]Weight NN:
# Build Chipmatch:     1/20...  rate=511.25 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
# [NNP_MasterGIRM_core cfg 0/3][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/20...  rate=4.05 Hz, etr: 0:00:04, ellapsed: 0:00:00, wall: 13:34 EST
# SVER:               20/20...  rate=4.05 Hz, etr: 0:00:00, ellapsed: 0:00:03, wall: 13:34 EST
#
# [mc4] query chunk:     1/1...  rate=0.06 Hz, etr: 0:00:00, ellapsed: 0:00:16, wall: 13:34 EST
# testnameid="NNP_MasterGIRM_core ['baseline:AQH=False,AI=True', 'baseline:AQH=True,AI=False', 'baseline:AQH=False,AI=False']['timectrl']"
# annot_cfgstr = _QSUUIDS((20)cjr43hke8koo4e7u)_DSUUIDS((92)w@th5%ilyps72bku)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_affine_invariance=False)_CHIP(sz450)
# pipe_hashstr = udipwbdwtdkmsfab
# [mc4] query chunk:     0/1...
# [NNP_MasterGIRM_core cfg 0/3][qreq] lazy loading
# [NNP_MasterGIRM_core cfg 0/3][aug] Requesting augmented nnindexer
# [NNP_MasterGIRM_core cfg 0/3][aug] Nothing to augment, fallback to memcache
# Assign NN:           1/20...  rate=5.68 Hz, etr: 0:00:03, ellapsed: 0:00:00, wall: 13:34 EST
# Assign NN:          20/20...  rate=5.68 Hz, etr: 0:00:00, ellapsed: 0:00:02, wall: 13:34 EST
#
# [NNP_MasterGIRM_core cfg 0/3][cache] 0/20 cache hits for neighbs4 in _ibeis_cache/neighborcache2
# Filter NN:           1/20...  rate=33553.31 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
# Filter NN:          20/20...  rate=33553.31 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
#
# [NNP_MasterGIRM_core cfg 0/3]Weight NN:
# Build Chipmatch:     1/20...  rate=1093.12 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 13:34 EST
# [NNP_MasterGIRM_core cfg 0/3][scoring] Making shortlist nNameShortList=50, nAnnotPerName=6
# SVER:                1/20...  rate=11.04 Hz, etr: 0:00:01, ellapsed: 0:00:00, wall: 13:34 EST
# SVER:               20/20...  rate=11.04 Hz, etr: 0:00:00, ellapsed: 0:00:01, wall: 13:34 EST
#
# [mc4] query chunk:     1/1...  rate=0.21 Hz, etr: 0:00:00, ellapsed: 0:00:04, wall: 13:34 EST
# /home/joncrall/code/ibeis/ibeis/experiments/experiment_harness.py:282: RuntimeWarning: divide by zero encountered in log
#   scorelogfactor = np.log(gt_raw_score) / np.log(gf_raw_score)

# %%
# Invariance + Time Experiment
test_result = ibeis.run_experiment(
    e='rank_cdf',
    db=db, 
    a=seperability_annot_cfgs, 
    t=['baseline:AQH=False,AI=True',
       'baseline:AQH=True,AI=False',
       'baseline:AQH=False,AI=False'])
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e rank_cdf --db NNP_MasterGIRM_core -a timequalctrl -t baseline:AQH=False,AI=True baseline:AQH=True,AI=False baseline:AQH=False,AI=False --show

# %% [markdown]
# # Score Seperability Experiments

# %% [markdown]
# ## Success Cases

# %%
# Score Seperability of Good Cases
test_result = ibeis.run_experiment(
    e='scores',
    db=db, 
    a=seperability_annot_cfgs, 
    t=['invarbest'],
    f=[':fail=False,min_gf_timedelta=None'],
)
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e scores --db NNP_MasterGIRM_core -a timequalctrl -t invarbest -f :fail=False,min_gf_timedelta=None --show
# testnameid="NNP_MasterGIRM_core ['invarbest']['timequalctrl']"
# annot_cfgstr = _QSUUIDS((20)cjr43hke8koo4e7u)_DSUUIDS((92)w@th5%ilyps72bku)
# pipe_cfgstr= _vsmany_NN(single,K4+1,padk=False,last,cks800)_NNWeight(lnbnn)_SV(0.01;2.0;1.57minIn=4,nNRR=50,nARR=6,nsum,cdl,+wi,+fc,)_AGG(nsum)_FLANN(8_kdtrees)_RRVsOne(False)_FEATWEIGHT(OFF)_FEAT(hesaff+sift_affine_invariance=False)_CHIP(sz450)_HACK(augment_queryside)
# pipe_hashstr = sckidzxjndpaqngn

# %% [markdown]
# ## All Cases

# %%
# Score Seperability with NO FILTERING
test_result = ibeis.run_experiment(
    e='scores',
    db=db, 
    a=seperability_annot_cfgs, 
    t=['invarbest'],
    f=[':fail=None,min_gf_timedelta=None']
)
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e scores --db NNP_MasterGIRM_core -a timequalctrl -t invarbest -f :fail=None,min_gf_timedelta=None --show

# %%
test_result = ibeis.run_experiment(
    e='taghist',
    db=db, 
    a=seperability_annot_cfgs, 
    t=['invarbest'],
    f=[':fail=None,min_gf_timedelta=None']
)
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e taghist --db NNP_MasterGIRM_core -a timequalctrl -t invarbest -f :fail=None,min_gf_timedelta=None --show

# %% [markdown]
# ## Success cases with large timedelta for groundfalse cases

# %%
# Score Seperability of Good Cases where large timedelta gf are gone
test_result = ibeis.run_experiment(
    e='scores',
    db=db, 
    a=seperability_annot_cfgs, 
    t=['invarbest'],
    f=[':fail=False,min_gf_timedelta=12h']
)
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e scores --db NNP_MasterGIRM_core -a timequalctrl -t invarbest -f :fail=False,min_gf_timedelta=12h --show

# %% [markdown]
# ## All cases with large timedelta for groundfalse cases

# %%
# Score Seperability of 
test_result = ibeis.run_experiment(
    e='scores',
    db=db, 
    a=seperability_annot_cfgs, 
    t=['baseline:AQH=True,AI=False'],
    f=[':fail=None,min_gf_timedelta=12h']
) 
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e scores --db NNP_MasterGIRM_core -a timequalctrl -t baseline:AQH=True,AI=False -f :fail=None,min_gf_timedelta=12h --show

# %%
# Investigate the reasons for the high scoring groundfalse cases
test_result = ibeis.run_experiment(
    e='taghist',
    db=db, 
    a=['timecontrolled'], 
    t=['invarbest'],
    f=[':fail=None,min_gf_timedelta=12h']
)
_ = test_result.draw_func()
# Out:
# Equivalent Command Line:
# ibeis -e taghist --db NNP_MasterGIRM_core -a timecontrolled -t invarbest -f :fail=None,min_gf_timedelta=12h --show
