# %%
# %pylab inline
from ibeis.experiments.experiment_drawing import *  # NOQA
from ibeis.init import main_helpers
ibs, test_result = main_helpers.testdata_expts('PZ_Master1', a=['timequalctrl'])
draw_casetag_hist(ibs, test_result)
ut.show_if_requested()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [harn.help] building acfg_list using ['timequalctrl']
# (1, 1)
# [util_io] ... cache exists: dpath=ACFG_CACHE cfgstr='PZ_Master1_cibykhruremvhygc'
# [util_io] * load_cPkl('ACFG_CACHE/ACFG_CACHEPZ_Master1_cibykhruremvhygc.cPkl')
# [util_io] ... cache hit
# [harn.help] parsed 1 / 1 unique annot configs
# [expt_help.get_pipecfg_list] building pipecfg_list using: ['default']
# [harn.help] return 1 / 1 unique pipeline configs
# [harn]================
# [harn] experiment_harness.test_configurations2()
# [harn] Testing 1 parameter configurations
# [harn]    with 1 annotations configurations
# [harn]    running 1 queries
# annot config    0/1...
# ---Annot config testnameid="PZ_Master1 ['default']['timequalctrl']"
# Constructing query requests
# Building qreq_    1/1...  rate=77.28 Hz, etr: 0:00:00, ellapsed: 0:00:00, wall: 15:54 EST
# ...

# %%
# %pylab inline
from ibeis.experiments.experiment_drawing import *  # NOQA
from ibeis.init import main_helpers
ibs, test_result = main_helpers.testdata_expts('PZ_Master1', a=['ctrl'], t=['baseline', 'invarbest']) # , 'invarbest'])
draw_rank_cdf(ibs, test_result) 
ut.show_if_requested()
# Out:
# WARNING: pylab import has clobbered these variables: ['split']
# `%matplotlib` prevents importing * from pylab and numpy
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1318: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# Populating the interactive namespace from numpy and matplotlib
#
# [ibs.__init__] new IBEISController
# [ibs._init_dirs] ibs.dbdir = '/media/raid/work/PZ_Master1'
# [util_io] * load_cPkl('PZ_Master1/general_config.cPkl')
# [ibs.__init__] END new IBEISController
#
# [harn.help] building acfg_list using ['ctrl']
# (1, 1)
# [util_io] ... cache exists: dpath=ACFG_CACHE cfgstr='PZ_Master1_pnwhljhqarnkhkba'
# [util_io] * load_cPkl('ACFG_CACHE/ACFG_CACHEPZ_Master1_pnwhljhqarnkhkba.cPkl')
# [util_io] ... cache hit
# ...
